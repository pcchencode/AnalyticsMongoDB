# %%
# !pip install dnspython
# Out:
# Collecting dnspython
#   Downloading https://files.pythonhosted.org/packages/ec/d3/3aa0e7213ef72b8585747aa0e271a9523e713813b9a20177ebe1e939deb0/dnspython-1.16.0-py2.py3-none-any.whl (188kB)
#      |████████████████████████████████| 194kB 738kB/s eta 0:00:01
# Installing collected packages: dnspython
# Successfully installed dnspython-1.16.0

# %%
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# Replace XXXX with your connection URI from the Atlas UI
client = MongoClient("mongodb+srv://gjgg:a1b2c3@mflix-wo96r.gcp.mongodb.net/test?retryWrites=true&w=majority")

# %%
db = client.mflix

# %%
collection = db.movie_initial

# %%
collection.find_one({'title':'The Big Short'})
# Out:
# {'_id': ObjectId('5e8532b36547bb5a2ec3bf89'),
#  'imdbID': 1596363,
#  'title': 'The Big Short',
#  'year': 2016,
#  'rating': '',
#  'runtime': '',
#  'genre': 'Drama',
#  'released': '',
#  'director': 'Adam McKay',
#  'writer': 'Michael Lewis (based on the book by), Adam McKay (screenplay), Charles Randolph (screenplay)',
#  'cast': 'Brad Pitt, Christian Bale, Selena Gomez, Karen Gillan',
#  'metacritic': '',
#  'imdbRating': '',
#  'imdbVotes': '',
#  'poster': '',
#  'plot': 'The men who made millions from a global economic meltdown.',
#  'fullplot': 'The men who made millions from a global economic meltdown.',
#  'language': '',
#  'country': 'USA',
#  'awards': '',
#  'lastupdated': '2015-09-12 00:20:34.633000000',
#  'type': 'movie'}

# %%
for result in collection.find({'title':'The Big Short'}):
    print(result)
    print('')
# Out:
# {'_id': ObjectId('5e8532b36547bb5a2ec3bf89'), 'imdbID': 1596363, 'title': 'The Big Short', 'year': 2016, 'rating': '', 'runtime': '', 'genre': 'Drama', 'released': '', 'director': 'Adam McKay', 'writer': 'Michael Lewis (based on the book by), Adam McKay (screenplay), Charles Randolph (screenplay)', 'cast': 'Brad Pitt, Christian Bale, Selena Gomez, Karen Gillan', 'metacritic': '', 'imdbRating': '', 'imdbVotes': '', 'poster': '', 'plot': 'The men who made millions from a global economic meltdown.', 'fullplot': 'The men who made millions from a global economic meltdown.', 'language': '', 'country': 'USA', 'awards': '', 'lastupdated': '2015-09-12 00:20:34.633000000', 'type': 'movie'}
#
# {'_id': ObjectId('5e8532c16547bb5a2ec3de3e'), 'imdbID': 1596363, 'title': 'The Big Short', 'year': 2016, 'rating': '', 'runtime': '', 'genre': 'Drama', 'released': '', 'director': 'Adam McKay', 'writer': 'Michael Lewis (based on the book by), Adam McKay (screenplay), Charles Randolph (screenplay)', 'cast': 'Brad Pitt, Selena Gomez, Christian Bale, Karen Gillan', 'metacritic': '', 'imdbRating': '', 'imdbVotes': '', 'poster': '', 'plot': 'The men who made millions from a global economic meltdown.', 'fullplot': 'The men who made millions from a global economic meltdown.', 'language': '', 'country': 'USA', 'awards': '', 'lastupdated': '2015-09-16 17:41:27.640000000', 'type': 'movie'}

# %% [markdown]
# ### 以下 aggregation 等價於 sql
# ```sql
# select language as lang, count(1)
# from movie_initial
# group by language
# ```

# %%
# aggregation
pipeline = [
    {
        '$group': {
            '_id': {"lang": "$language"},
            'count': {'$sum': 1}
        }
    }
]

clear_output()
pprint.pprint(list(client.mflix.movie_initial.aggregate(pipeline)))
# Out:
# [{'_id': {'lang': 'English, Mandarin, French, German, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'Catalan'}, 'count': 5},
#  {'_id': {'lang': 'English, French, German, Dutch, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, French, German'}, 'count': 6},
#  {'_id': {'lang': 'English, Latin, Welsh'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'Flemish, Italian, French'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, English, Hindi, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'Polish, Russian, Estonian'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Tamil, Telugu'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Korean, English'}, 'count': 1},
#  {'_id': {'lang': 'Polish, Serbo-Croatian'}, 'count': 1},
#  {'_id': {'lang': 'Croatian, Serbian'}, 'count': 2},
#  {'_id': {'lang': 'English, Hebrew, Aramaic, Yiddish, French'}, 'count': 2},
#  {'_id': {'lang': 'English, Navajo, Spanish'}, 'count': 3},
#  {'_id': {'lang': 'Italian, French, German'}, 'count': 4},
#  {'_id': {'lang': 'English, Swedish, Persian'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, English, Panjabi'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, English, Chinese, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Ukrainian, Italian, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Mongolian, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, Panjabi, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, Arabic, French, Turkish, English'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Danish, French'}, 'count': 1},
#  {'_id': {'lang': 'Italian, German, Neapolitan, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'French, Romanian, Romany'}, 'count': 1},
#  {'_id': {'lang': 'English, Vietnamese, Spanish, Thai'}, 'count': 1},
#  {'_id': {'lang': 'English, Sinhalese'}, 'count': 1},
#  {'_id': {'lang': 'Flemish, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'French, English, Serbian, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'Thai, Japanese, Burmese'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Czech'}, 'count': 1},
#  {'_id': {'lang': 'English, Bosnian, Spanish, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Serbo-Croatian, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Indonesian'}, 'count': 9},
#  {'_id': {'lang': 'Dutch, Arabic, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Lithuanian'}, 'count': 2},
#  {'_id': {'lang': 'Polish, French, German, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Arabic, French'}, 'count': 6},
#  {'_id': {'lang': 'Danish, French'}, 'count': 1},
#  {'_id': {'lang': 'Polish, Danish'}, 'count': 1},
#  {'_id': {'lang': 'Armenian, Kurdish, Russian, French'}, 'count': 1},
#  {'_id': {'lang': 'Serbian, German'}, 'count': 3},
#  {'_id': {'lang': 'Armenian'}, 'count': 3},
#  {'_id': {'lang': 'English, Irish, Latin'}, 'count': 1},
#  {'_id': {'lang': 'English, Afrikaans, Xhosa'}, 'count': 2},
#  {'_id': {'lang': 'Cantonese, English, Malay'}, 'count': 2},
#  {'_id': {'lang': 'Japanese, English, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Greek, Italian'}, 'count': 3},
#  {'_id': {'lang': 'Italian, French, English'}, 'count': 6},
#  {'_id': {'lang': 'Chinese'}, 'count': 33},
#  {'_id': {'lang': 'Hindi, English, Konkani'}, 'count': 1},
#  {'_id': {'lang': 'Serbian, English'}, 'count': 3},
#  {'_id': {'lang': 'English, Syriac, Assyrian Neo-Aramaic'}, 'count': 1},
#  {'_id': {'lang': 'Hebrew, Amharic, Swahili, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Swedish, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'Danish, German, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Russian, German'}, 'count': 27},
#  {'_id': {'lang': 'Russian, English, Azerbaijani'}, 'count': 1},
#  {'_id': {'lang': 'Kazakh, Russian, French'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Portuguese'}, 'count': 4},
#  {'_id': {'lang': 'English, German, French, Spanish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Norwegian'}, 'count': 8},
#  {'_id': {'lang': 'Italian, Ukrainian'}, 'count': 1},
#  {'_id': {'lang': 'Serbian, Hungarian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, German, Russian'}, 'count': 2},
#  {'_id': {'lang': 'Tamil, Hindi, Marathi, Telugu'}, 'count': 1},
#  {'_id': {'lang': 'Romany, Serbian, Bulgarian'}, 'count': 1},
#  {'_id': {'lang': 'Russian, Italian, English'}, 'count': 2},
#  {'_id': {'lang': 'Hungarian'}, 'count': 80},
#  {'_id': {'lang': 'Spanish, English, Portuguese'}, 'count': 5},
#  {'_id': {'lang': 'German, Greek'}, 'count': 2},
#  {'_id': {'lang': 'Russian, English, Ukrainian'}, 'count': 2},
#  {'_id': {'lang': 'English, Shoshoni, Spanish, French'}, 'count': 1},
#  {'_id': {'lang': 'Albanian, Italian'}, 'count': 3},
#  {'_id': {'lang': 'French, Dutch, English'}, 'count': 2},
#  {'_id': {'lang': 'German, English, French, Hebrew, Latin'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Marathi'}, 'count': 2},
#  {'_id': {'lang': 'German, English, Japanese, Portuguese, Nyanja, Hindi'},
#   'count': 1},
#  {'_id': {'lang': 'Afrikaans, English, Ungwatsi'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Spanish, Norwegian'}, 'count': 1},
#  {'_id': {'lang': 'English, Japanese, Korean'}, 'count': 3},
#  {'_id': {'lang': 'English, Maya'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Hebrew, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'German, Serbo-Croatian, Bosnian, English'}, 'count': 1},
#  {'_id': {'lang': 'Norwegian, English, Swedish, Saami'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Arabic, Hindi'}, 'count': 1},
#  {'_id': {'lang': 'Arabic, English'}, 'count': 9},
#  {'_id': {'lang': 'Italian, English, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, Swedish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Latin'}, 'count': 61},
#  {'_id': {'lang': 'Spanish, Aymara'}, 'count': 2},
#  {'_id': {'lang': 'Flemish, Dutch, English, French'}, 'count': 1},
#  {'_id': {'lang': 'German, Russian, Polish, Romanian, Bulgarian, Czech'},
#   'count': 1},
#  {'_id': {'lang': 'Greek, Albanian, German'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Spanish, German, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'French, Arabic, English, Hebrew, Serbo-Croatian, Spanish'},
#   'count': 1},
#  {'_id': {'lang': 'English, French, Japanese'}, 'count': 9},
#  {'_id': {'lang': 'Swedish, Finnish, French, German'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Urdu, Bengali'}, 'count': 1},
#  {'_id': {'lang': 'Greek, Turkish, German'}, 'count': 1},
#  {'_id': {'lang': 'English, French, German, Russian, Japanese, Latin'},
#   'count': 1},
#  {'_id': {'lang': 'Korean, French, English'}, 'count': 2},
#  {'_id': {'lang': 'Russian, Romany'}, 'count': 1},
#  {'_id': {'lang': 'English, Romanian, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, English, Urdu, German'}, 'count': 2},
#  {'_id': {'lang': 'Bulgarian, German, Italian, Slovenian, English, Hungarian'},
#   'count': 1},
#  {'_id': {'lang': 'Greek, German, Romanian'}, 'count': 1},
#  {'_id': {'lang': 'Aboriginal, English, French, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Russian, French, Flemish'}, 'count': 1},
#  {'_id': {'lang': 'Hungarian, Yiddish, German, Polish'}, 'count': 1},
#  {'_id': {'lang': 'Czech, English, German, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Latin, German'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Cantonese, German'}, 'count': 1},
#  {'_id': {'lang': 'French, Italian, Romanian'}, 'count': 1},
#  {'_id': {'lang': 'French, English, German, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, Finnish, Spanish, English'}, 'count': 1},
#  {'_id': {'lang': 'German, Swiss German, English, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'Russian, Turkish, Georgian, Chechen'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, German, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Portuguese, English, French, Spanish'}, 'count': 3},
#  {'_id': {'lang': 'Hindi, Telugu'}, 'count': 3},
#  {'_id': {'lang': 'Japanese, Cantonese, English'}, 'count': 2},
#  {'_id': {'lang': 'German, Inuktitut'}, 'count': 1},
#  {'_id': {'lang': 'Flemish, French, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Bulgarian, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, Bulgarian, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Scots, Latin'}, 'count': 1},
#  {'_id': {'lang': 'French, English, German, Spanish, Polish'}, 'count': 1},
#  {'_id': {'lang': 'English, Danish, Spanish, Albanian, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'German, Russian, English, Hebrew'}, 'count': 1},
#  {'_id': {'lang': 'Serbian, Czech'}, 'count': 2},
#  {'_id': {'lang': 'French, Serbo-Croatian, English'}, 'count': 1},
#  {'_id': {'lang': 'Japanese, Marshallese'}, 'count': 1},
#  {'_id': {'lang': 'Greek, Albanian, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Japanese, Mandarin'}, 'count': 5},
#  {'_id': {'lang': 'English, Japanese, Italian, French'}, 'count': 2},
#  {'_id': {'lang': 'English, Mandarin, Russian, Japanese, Portuguese, '
#                   'Cantonese'},
#   'count': 2},
#  {'_id': {'lang': 'Cantonese, Mandarin, English, Shanghainese, French'},
#   'count': 2},
#  {'_id': {'lang': 'English, Greek, German, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, Scottish Gaelic'}, 'count': 11},
#  {'_id': {'lang': 'Czech, English, Japanese'}, 'count': 2},
#  {'_id': {'lang': 'Dari, English, Pushto, Russian, Urdu'}, 'count': 1},
#  {'_id': {'lang': 'Persian, English'}, 'count': 5},
#  {'_id': {'lang': 'Danish, English, Romanian, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Swedish, American Sign Language'},
#   'count': 1},
#  {'_id': {'lang': 'Tamil, Sinhalese, English'}, 'count': 1},
#  {'_id': {'lang': 'French, English, Greek, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Serbo-Croatian, Macedonian, Romany'}, 'count': 1},
#  {'_id': {'lang': 'Portuguese, English, Russian, French'}, 'count': 1},
#  {'_id': {'lang': 'Japanese, Mandarin, Tagalog'}, 'count': 1},
#  {'_id': {'lang': 'English, Hindi, German'}, 'count': 1},
#  {'_id': {'lang': 'English, German, French, Russian'}, 'count': 4},
#  {'_id': {'lang': 'Greek'}, 'count': 116},
#  {'_id': {'lang': 'German, English, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'English, British Sign Language'}, 'count': 2},
#  {'_id': {'lang': 'Japanese, English, Catalan'}, 'count': 1},
#  {'_id': {'lang': 'English, Hungarian, Latin, Danish'}, 'count': 1},
#  {'_id': {'lang': 'Catalan, English'}, 'count': 2},
#  {'_id': {'lang': 'Finnish, English, Swedish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Czech, German'}, 'count': 7},
#  {'_id': {'lang': 'English, French, Japanese, Russian, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Georgian'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Vietnamese'}, 'count': 1},
#  {'_id': {'lang': 'Filipino, Tagalog, English'}, 'count': 12},
#  {'_id': {'lang': 'English, German, Greek'}, 'count': 2},
#  {'_id': {'lang': 'English, French, Spanish, German'}, 'count': 2},
#  {'_id': {'lang': 'English, Swahili, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'French, English, Spanish, German, Italian, Russian'},
#   'count': 1},
#  {'_id': {'lang': 'German, Turkish, English, Mandarin, French'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Arabic, French, Portuguese, Russian, '
#                   'Slovak'},
#   'count': 2},
#  {'_id': {'lang': 'Estonian, English'}, 'count': 1},
#  {'_id': {'lang': 'French, Greek, German, English'}, 'count': 1},
#  {'_id': {'lang': 'Romanian, French, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Hindi, Spanish'}, 'count': 2},
#  {'_id': {'lang': 'Amharic, English, German'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Sardinian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Turkish, German, Greek, Italian'},
#   'count': 1},
#  {'_id': {'lang': 'Mongolian'}, 'count': 4},
#  {'_id': {'lang': 'English, Portuguese, Karaj�'}, 'count': 1},
#  {'_id': {'lang': 'Romanian, Hungarian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Italian, Spanish, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'Bulgarian, Russian'}, 'count': 1},
#  {'_id': {'lang': 'German, Quechua, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Danish, Swedish, English'}, 'count': 2},
#  {'_id': {'lang': 'Russian, English, French, German'}, 'count': 1},
#  {'_id': {'lang': 'Persian, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Arabic, English, French'}, 'count': 2},
#  {'_id': {'lang': 'English, Spanish, Bulgarian'}, 'count': 1},
#  {'_id': {'lang': 'Danish, Swedish, Norwegian'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Flemish'}, 'count': 1},
#  {'_id': {'lang': 'English, Japanese, Esperanto'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Serbian, Croatian'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Urdu, English, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Korean, Indonesian'}, 'count': 1},
#  {'_id': {'lang': 'German, Swahili, English'}, 'count': 1},
#  {'_id': {'lang': 'Italian, English, French, German'}, 'count': 3},
#  {'_id': {'lang': 'English, Korean, French'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, French'}, 'count': 2},
#  {'_id': {'lang': 'French, Japanese, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'English, Chinese, Spanish'}, 'count': 2},
#  {'_id': {'lang': 'Luxembourgish'}, 'count': 1},
#  {'_id': {'lang': 'English, Gujarati'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Hebrew, French, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Shoshoni, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, German, French'}, 'count': 1},
#  {'_id': {'lang': 'Russian, German, Georgian, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Greek, Yiddish, German'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Spanish, Korean'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, French, Hawaiian, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Greek, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Indonesian'}, 'count': 20},
#  {'_id': {'lang': 'Portuguese, Spanish, English'}, 'count': 3},
#  {'_id': {'lang': 'English, Russian, Italian'}, 'count': 3},
#  {'_id': {'lang': 'Japanese, Mandarin'}, 'count': 9},
#  {'_id': {'lang': 'English, French, Cantonese, Gujarati, Yiddish'}, 'count': 1},
#  {'_id': {'lang': 'Basque, Spanish'}, 'count': 4},
#  {'_id': {'lang': 'Hebrew, Dutch, Polish'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Bosnian, Serbian'}, 'count': 1},
#  {'_id': {'lang': 'English, Japanese, Mandarin, Russian, Cantonese'},
#   'count': 1},
#  {'_id': {'lang': 'French, English, Mandarin, Italian, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, French, Yiddish, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, Estonian, Danish'}, 'count': 3},
#  {'_id': {'lang': 'Japanese, Latin'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, French, Italian'}, 'count': 1},
#  {'_id': {'lang': 'French, Arabic, Hebrew'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, Arabic'}, 'count': 2},
#  {'_id': {'lang': 'German, French, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, English, German, French'}, 'count': 1},
#  {'_id': {'lang': 'Norwegian, Swedish, Saami'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Min Nan, Japanese'}, 'count': 2},
#  {'_id': {'lang': 'English, French, Italian, German, Romany'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, Norwegian, English'}, 'count': 1},
#  {'_id': {'lang': 'Tamil, Telugu'}, 'count': 15},
#  {'_id': {'lang': 'Norwegian, German'}, 'count': 1},
#  {'_id': {'lang': 'Lithuanian, French, Russian, English'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Polish, French'}, 'count': 3},
#  {'_id': {'lang': 'Russian, English, Chechen'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Occitan, French'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, Russian, Finnish'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, Japanese'}, 'count': 3},
#  {'_id': {'lang': 'Dutch, English, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Romanian, English, French'}, 'count': 1},
#  {'_id': {'lang': 'Portuguese, Cantonese, English'}, 'count': 1},
#  {'_id': {'lang': 'Telugu'}, 'count': 33},
#  {'_id': {'lang': 'Swedish, Icelandic'}, 'count': 1},
#  {'_id': {'lang': 'English, Norse,  Old, Latin'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, English, Italian, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'Flemish, English'}, 'count': 1},
#  {'_id': {'lang': 'French, German, Polish'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, German'}, 'count': 10},
#  {'_id': {'lang': 'French, English, Hebrew'}, 'count': 2},
#  {'_id': {'lang': 'Greek, German, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Hebrew, English, Tagalog, German'}, 'count': 1},
#  {'_id': {'lang': 'French, Hindi, Arabic, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Maya, Spanish, Greek, German'}, 'count': 1},
#  {'_id': {'lang': 'French, Flemish'}, 'count': 3},
#  {'_id': {'lang': 'Italian, German, Latin, English, Spanish, Polish, French'},
#   'count': 1},
#  {'_id': {'lang': 'Danish, German'}, 'count': 4},
#  {'_id': {'lang': 'English, French, Spanish'}, 'count': 39},
#  {'_id': {'lang': 'Hindi'}, 'count': 498},
#  {'_id': {'lang': 'English, Ukrainian, German, Spanish, Russian, French, '
#                   'Arabic, Turkish'},
#   'count': 1},
#  {'_id': {'lang': 'English, Korean, French, Vietnamese'}, 'count': 1},
#  {'_id': {'lang': 'English, Polish, German, French, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, French, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'French, Polish, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Swedish, Thai'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Mandarin, German, Japanese, English, Ukrainian'},
#   'count': 1},
#  {'_id': {'lang': 'English, Klingon'}, 'count': 9},
#  {'_id': {'lang': 'Swedish, German, English, Spanish, French, Russian'},
#   'count': 1},
#  {'_id': {'lang': 'French, English, Polish'}, 'count': 3},
#  {'_id': {'lang': 'English, Icelandic, Swahili, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Saami'}, 'count': 1},
#  {'_id': {'lang': 'Japanese, French, English'}, 'count': 3},
#  {'_id': {'lang': 'Greenlandic, English'}, 'count': 1},
#  {'_id': {'lang': 'Telugu, Tamil, Hindi, Urdu, English'}, 'count': 1},
#  {'_id': {'lang': 'French, Dutch, English, Italian'}, 'count': 1},
#  {'_id': {'lang': 'German, Hebrew, Yiddish'}, 'count': 1},
#  {'_id': {'lang': 'German, English, French, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Catalan, Spanish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Bulgarian'}, 'count': 1},
#  {'_id': {'lang': 'English, Yiddish, Hebrew'}, 'count': 3},
#  {'_id': {'lang': 'Georgian, Russian, French, English'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Flemish, Latin, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'English, Japanese, Navajo'}, 'count': 1},
#  {'_id': {'lang': 'French, Romany'}, 'count': 1},
#  {'_id': {'lang': 'Wolof, French'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Mandarin, Polish, English, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Syriac'}, 'count': 1},
#  {'_id': {'lang': 'English, Romanian, Spanish, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, French, Afrikaans'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Hungarian'}, 'count': 2},
#  {'_id': {'lang': 'Swiss German, German, French'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Japanese, Danish, English'}, 'count': 1},
#  {'_id': {'lang': 'French, English, German'}, 'count': 16},
#  {'_id': {'lang': 'Korean, French'}, 'count': 5},
#  {'_id': {'lang': 'English, Swedish, German, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, English, Bengali'}, 'count': 1},
#  {'_id': {'lang': 'Kurdish, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'French, Italian, Spanish'}, 'count': 2},
#  {'_id': {'lang': 'German, Serbian, Serbo-Croatian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, German, Italian'}, 'count': 10},
#  {'_id': {'lang': 'Portuguese, Creole'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Dari, English, Urdu'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Maya'}, 'count': 1},
#  {'_id': {'lang': 'Georgian, Russian, Italian, German'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, English'}, 'count': 102},
#  {'_id': {'lang': 'French, Occitan'}, 'count': 3},
#  {'_id': {'lang': 'French, English, Danish'}, 'count': 1},
#  {'_id': {'lang': 'English, Macedonian, German, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Basque'}, 'count': 4},
#  {'_id': {'lang': 'English, French, Hindi, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Mohawk'}, 'count': 1},
#  {'_id': {'lang': 'English, Burmese'}, 'count': 2},
#  {'_id': {'lang': 'Hebrew, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'Arabic, Danish'}, 'count': 2},
#  {'_id': {'lang': 'French, Arabic, Corsican'}, 'count': 1},
#  {'_id': {'lang': 'English, Sign Languages'}, 'count': 2},
#  {'_id': {'lang': 'Spanish, Bable'}, 'count': 1},
#  {'_id': {'lang': 'English, Hindi, Panjabi, Rajasthani'}, 'count': 1},
#  {'_id': {'lang': 'Danish, Swedish, English, Japanese, Somali'}, 'count': 1},
#  {'_id': {'lang': 'German, Japanese, Hungarian'}, 'count': 2},
#  {'_id': {'lang': 'English, Amharic, Khmer, German, Chechen'}, 'count': 1},
#  {'_id': {'lang': 'Czech, Romany, English'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Czech, English, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Vietnamese, Swahili'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, Ukrainian'}, 'count': 2},
#  {'_id': {'lang': 'Latvian, Russian'}, 'count': 2},
#  {'_id': {'lang': 'Hebrew, Russian, English'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Spanish, English'}, 'count': 5},
#  {'_id': {'lang': 'Mandarin, English, French'}, 'count': 2},
#  {'_id': {'lang': 'Norwegian, English, French, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, French, German'}, 'count': 7},
#  {'_id': {'lang': 'English, Italian, Latin, French, Swiss German, German, '
#                   'Chinese'},
#   'count': 1},
#  {'_id': {'lang': 'English, Vietnamese, German, Danish'}, 'count': 1},
#  {'_id': {'lang': 'French, Dutch, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, English'}, 'count': 29},
#  {'_id': {'lang': 'Italian, Neapolitan'}, 'count': 3},
#  {'_id': {'lang': 'English, Somali'}, 'count': 2},
#  {'_id': {'lang': 'German, English, Czech'}, 'count': 1},
#  {'_id': {'lang': 'French, Russian, German, Greek'}, 'count': 1},
#  {'_id': {'lang': 'French, German, Occitan'}, 'count': 1},
#  {'_id': {'lang': 'Romanian, Turkish, Romany'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, German, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Japanese, Mandarin, Min Nan'}, 'count': 2},
#  {'_id': {'lang': 'Polish, English, German, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Italian, French, Spanish, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Mandarin, Malay, Korean'}, 'count': 1},
#  {'_id': {'lang': 'French, Hungarian, English'}, 'count': 1},
#  {'_id': {'lang': 'Flemish, French, Dutch'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Spanish, Russian'}, 'count': 2},
#  {'_id': {'lang': 'Purepecha, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Min Nan, Japanese, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Yoruba'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, Scanian'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Slovenian, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Danish, German'}, 'count': 5},
#  {'_id': {'lang': 'English, Romanian, Russian, Serbian'}, 'count': 1},
#  {'_id': {'lang': 'Icelandic, English, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Tagalog, Japanese, Filipino'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, American Sign Language'}, 'count': 1},
#  {'_id': {'lang': 'Icelandic, Danish'}, 'count': 2},
#  {'_id': {'lang': 'Mandarin, Cantonese, English, Arabic, Malay'}, 'count': 1},
#  {'_id': {'lang': 'Russian, Catalan, Finnish, German'}, 'count': 1},
#  {'_id': {'lang': 'French, Czech, English'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Maya, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Russian'}, 'count': 4},
#  {'_id': {'lang': 'Korean, Thai, English, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, English, Russian, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Danish, Icelandic, English, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Korean, English, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Spanish, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Japanese, Korean'}, 'count': 5},
#  {'_id': {'lang': 'Mandarin, Min Nan, English'}, 'count': 2},
#  {'_id': {'lang': 'Czech, English'}, 'count': 3},
#  {'_id': {'lang': 'German, Russian, Lithuanian, Ukrainian'}, 'count': 1},
#  {'_id': {'lang': 'French, Italian, English, German'}, 'count': 2},
#  {'_id': {'lang': 'English, Swahili'}, 'count': 8},
#  {'_id': {'lang': 'Hungarian, Romanian'}, 'count': 2},
#  {'_id': {'lang': 'English, Mandarin, Malay'}, 'count': 1},
#  {'_id': {'lang': 'English, French, German, Greek,  Ancient (to 1453)'},
#   'count': 1},
#  {'_id': {'lang': 'Thai, English, Japanese, Korean'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, French, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Dutch, Spanish, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Danish'}, 'count': 157},
#  {'_id': {'lang': 'Hindi, Tibetan'}, 'count': 1},
#  {'_id': {'lang': 'German, English, Romany'}, 'count': 2},
#  {'_id': {'lang': 'English, American Sign Language, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Arabic, French, German, Russian, Czech, Slovak, '
#                   'Dari, Pushto'},
#   'count': 1},
#  {'_id': {'lang': 'English, Arabic, French, Hebrew, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Hungarian, Slovak'}, 'count': 2},
#  {'_id': {'lang': 'English, German, Norwegian'}, 'count': 2},
#  {'_id': {'lang': 'German, English, Hindi'}, 'count': 1},
#  {'_id': {'lang': 'English, American Sign Language, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Japanese'}, 'count': 5},
#  {'_id': {'lang': 'Swedish, Hungarian, German'}, 'count': 2},
#  {'_id': {'lang': 'Japanese, Japanese Sign Language'}, 'count': 1},
#  {'_id': {'lang': 'Portuguese, German'}, 'count': 4},
#  {'_id': {'lang': 'English, Slovenian'}, 'count': 1},
#  {'_id': {'lang': 'Scots, German'}, 'count': 1},
#  {'_id': {'lang': 'Romanian, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Greek, French'}, 'count': 3},
#  {'_id': {'lang': 'Hungarian, English, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Portuguese, Yoruba'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, Turkish, Ukrainian, Urdu'}, 'count': 1},
#  {'_id': {'lang': 'Hebrew, Arabic'}, 'count': 6},
#  {'_id': {'lang': 'Urdu, English, Panjabi, Arabic, Pushto'}, 'count': 1},
#  {'_id': {'lang': 'French, Spanish, Italian, Polish'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Shanxi'}, 'count': 1},
#  {'_id': {'lang': 'French, Sign Languages'}, 'count': 1},
#  {'_id': {'lang': 'Serbo-Croatian, French'}, 'count': 2},
#  {'_id': {'lang': 'Russian, English, Serbo-Croatian'}, 'count': 1},
#  {'_id': {'lang': 'Flemish, Dutch, French'}, 'count': 1},
#  {'_id': {'lang': 'Telugu, Tamil, Hindi, Malayalam, Chinese, Urdu, Thai, '
#                   'Japanese, Portuguese, Kannada'},
#   'count': 1},
#  {'_id': {'lang': 'Icelandic, English'}, 'count': 5},
#  {'_id': {'lang': 'English, German, Czech, Romanian'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Min Nan, Japanese, Cantonese'}, 'count': 1},
#  {'_id': {'lang': 'French, Spanish, English'}, 'count': 4},
#  {'_id': {'lang': 'French, German, English, Italian, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Russian, Arabic, French'}, 'count': 1},
#  {'_id': {'lang': 'German, Japanese, English'}, 'count': 1},
#  {'_id': {'lang': 'Polish, Russian'}, 'count': 3},
#  {'_id': {'lang': 'Japanese, English, German, French'}, 'count': 1},
#  {'_id': {'lang': 'Greek, Turkish, English'}, 'count': 2},
#  {'_id': {'lang': 'Korean, English, Filipino'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, English, Gujarati, Panjabi, Urdu'}, 'count': 1},
#  {'_id': {'lang': 'German'}, 'count': 674},
#  {'_id': {'lang': 'Hebrew, English, German, Arabic, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Japanese, Mandarin'}, 'count': 2},
#  {'_id': {'lang': 'Tupi, French, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, German'}, 'count': 2},
#  {'_id': {'lang': 'English, Quechua, Romanian, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Azerbaijani, Georgian'}, 'count': 1},
#  {'_id': {'lang': 'Flemish, French'}, 'count': 1},
#  {'_id': {'lang': 'English, American Sign Language'}, 'count': 30},
#  {'_id': {'lang': 'Cantonese, English, Mandarin, Malay, Thai'}, 'count': 1},
#  {'_id': {'lang': 'German, Turkish'}, 'count': 11},
#  {'_id': {'lang': 'French, Thai, English, Lao'}, 'count': 1},
#  {'_id': {'lang': 'Korean'}, 'count': 377},
#  {'_id': {'lang': 'English, Arabic, Hebrew, Greek'}, 'count': 1},
#  {'_id': {'lang': 'Arabic, English, Hebrew'}, 'count': 7},
#  {'_id': {'lang': 'French, English, German, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, Spanish, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Amharic'}, 'count': 1},
#  {'_id': {'lang': 'German, Russian'}, 'count': 7},
#  {'_id': {'lang': 'Icelandic, Swedish, English, Spanish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Dutch, French, German, Lithuanian'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'Turkish, French'}, 'count': 2},
#  {'_id': {'lang': 'English, Swahili, French'}, 'count': 2},
#  {'_id': {'lang': 'Tamil, Hindi'}, 'count': 5},
#  {'_id': {'lang': 'Swedish, English, Norwegian'}, 'count': 2},
#  {'_id': {'lang': 'French, Arabic, Bambara, English, Songhay'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Korean, Russian'}, 'count': 1},
#  {'_id': {'lang': 'French, Albanian'}, 'count': 1},
#  {'_id': {'lang': 'Marathi, Hindi'}, 'count': 1},
#  {'_id': {'lang': 'English, Middle English'}, 'count': 1},
#  {'_id': {'lang': 'Bambara, Fulah'}, 'count': 1},
#  {'_id': {'lang': 'Danish, Faroese'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, German, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Hindi, Manipuri, Xhosa'}, 'count': 1},
#  {'_id': {'lang': 'Turkish, Kurdish, Dutch'}, 'count': 1},
#  {'_id': {'lang': 'English, Korean, Persian, Spanish, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Urdu, Assamese, Tamil, Telugu'}, 'count': 1},
#  {'_id': {'lang': 'Polish, Italian'}, 'count': 3},
#  {'_id': {'lang': 'English, French, Arabic, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Catalan, English'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Latin'}, 'count': 7},
#  {'_id': {'lang': 'English, Spanish Sign Language'}, 'count': 1},
#  {'_id': {'lang': 'German, Russian, Polish, Hebrew'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Vietnamese, Khmer'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, English, Danish, Latvian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, German, Swedish, Italian, Russian'},
#   'count': 1},
#  {'_id': {'lang': 'English, Spanish, Latin'}, 'count': 7},
#  {'_id': {'lang': 'Pushto, Persian, English, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'English, Xhosa'}, 'count': 2},
#  {'_id': {'lang': 'English, Arabic, German'}, 'count': 2},
#  {'_id': {'lang': 'English, French, Arabic, Romanian'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Romany, Romanian, Macedonian, Hindi'},
#   'count': 1},
#  {'_id': {'lang': 'English, German, Kazakh, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Korean'}, 'count': 2},
#  {'_id': {'lang': 'Italian, French, German, English, Czech, Latin, Hungarian, '
#                   'Neapolitan'},
#   'count': 1},
#  {'_id': {'lang': 'English, Dutch, Irish, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Cantonese, Mandarin'}, 'count': 5},
#  {'_id': {'lang': 'English, French, North American Indian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, German, Danish'}, 'count': 1},
#  {'_id': {'lang': 'English, Zulu, Afrikaans, Southern Sotho'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Russian, English'}, 'count': 2},
#  {'_id': {'lang': 'French, Georgian, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Italian, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Estonian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Italian, Russian, Spanish'}, 'count': 2},
#  {'_id': {'lang': 'English, Russian, Serbo-Croatian'}, 'count': 1},
#  {'_id': {'lang': 'English, Swahili, Kirundi, French'}, 'count': 1},
#  {'_id': {'lang': 'Korean, English, Japanese, Cantonese, Mandarin'},
#   'count': 1},
#  {'_id': {'lang': 'English, Polish, Yiddish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Turkish, Sign Languages'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Tamil, Telugu, Chinese, English'}, 'count': 2},
#  {'_id': {'lang': 'French, English, Norwegian'}, 'count': 1},
#  {'_id': {'lang': 'English, Crow, French'}, 'count': 1},
#  {'_id': {'lang': 'German, Italian'}, 'count': 13},
#  {'_id': {'lang': 'Polish, French, Russian, German, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, Slovak, Italian, Czech'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Tagalog'}, 'count': 3},
#  {'_id': {'lang': 'Mandarin, Japanese, Vietnamese'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, Czech'}, 'count': 1},
#  {'_id': {'lang': 'Czech'}, 'count': 106},
#  {'_id': {'lang': 'English, German, Italian, Japanese, Amharic, Russian'},
#   'count': 1},
#  {'_id': {'lang': 'English, Spanish, Korean'}, 'count': 5},
#  {'_id': {'lang': 'English, Russian, Esperanto'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, English, Thai'}, 'count': 3},
#  {'_id': {'lang': 'English, Khmer'}, 'count': 2},
#  {'_id': {'lang': 'Danish, English, Dari'}, 'count': 1},
#  {'_id': {'lang': 'English, Czech, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'English, Vietnamese, German'}, 'count': 1},
#  {'_id': {'lang': 'French, German, English, Italian, Russian, Spanish'},
#   'count': 1},
#  {'_id': {'lang': 'English, Polish, Swedish'}, 'count': 2},
#  {'_id': {'lang': 'English, Afrikaans, Ungwatsi'}, 'count': 1},
#  {'_id': {'lang': 'French, German, Korean, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'English, Mandarin, Tibetan'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Japanese, German, French, Korean'},
#   'count': 1},
#  {'_id': {'lang': 'Swedish, Norwegian, English, German'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Neapolitan, English'}, 'count': 1},
#  {'_id': {'lang': 'Russian, German, Spanish, English, Latin'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, English, French, Latin, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Russian, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Egyptian (Ancient), Arabic'}, 'count': 2},
#  {'_id': {'lang': 'Cantonese, Mandarin, Korean'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Shanghainese, Tagalog, English, Mandarin'},
#   'count': 1},
#  {'_id': {'lang': 'English, Creole'}, 'count': 2},
#  {'_id': {'lang': 'English, French, Armenian'}, 'count': 1},
#  {'_id': {'lang': 'Flemish, Dutch'}, 'count': 4},
#  {'_id': {'lang': 'English, Ibo, Yoruba, Hausa'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Polish, Swedish, German, Italian, Czech'},
#   'count': 1},
#  {'_id': {'lang': 'English, Spanish, Italian, French, Swiss German, German'},
#   'count': 1},
#  {'_id': {'lang': 'Hindi, Gujarati, Marathi, Panjabi, Tamil, English'},
#   'count': 1},
#  {'_id': {'lang': 'Polish, Russian, English, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, French'}, 'count': 22},
#  {'_id': {'lang': 'Czech, English, Dutch'}, 'count': 1},
#  {'_id': {'lang': 'Serbian, Albanian'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, German'}, 'count': 2},
#  {'_id': {'lang': 'Acholi, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Turkish, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'English, Aboriginal'}, 'count': 5},
#  {'_id': {'lang': 'English, Bosnian'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Swiss German, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'English, Hindi, Mandarin, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Spanish, Italian'}, 'count': 2},
#  {'_id': {'lang': 'English, German, Swahili'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Mandarin, Tibetan, Hindi'}, 'count': 1},
#  {'_id': {'lang': 'Romany, Serbo-Croatian, Italian, English'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, English, Serbian, Norwegian'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, German'}, 'count': 2},
#  {'_id': {'lang': 'English, Serbo-Croatian, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Chinese, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Vietnamese'}, 'count': 3},
#  {'_id': {'lang': 'English, Somali, Spanish, French'}, 'count': 1},
#  {'_id': {'lang': 'Estonian, Russian, German, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Cantonese, Japanese'}, 'count': 2},
#  {'_id': {'lang': 'German, French, English, Thai, Japanese, Spanish, Bengali'},
#   'count': 1},
#  {'_id': {'lang': 'Italian, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Finnish, Italian, German'}, 'count': 1},
#  {'_id': {'lang': 'Korean, Korean Sign Language'}, 'count': 1},
#  {'_id': {'lang': 'Serbian, Albanian, Slovenian, German'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Quechua, French, English, Persian'}, 'count': 1},
#  {'_id': {'lang': 'Arabic, French'}, 'count': 14},
#  {'_id': {'lang': 'Italian, Greek, French, Neapolitan'}, 'count': 1},
#  {'_id': {'lang': 'German, Russian, Serbian'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Gallegan'}, 'count': 1},
#  {'_id': {'lang': 'Norwegian, Swedish'}, 'count': 16},
#  {'_id': {'lang': 'English, French, German, Polish'}, 'count': 1},
#  {'_id': {'lang': 'Italian, German, French, Hungarian, English'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Romanian'}, 'count': 1},
#  {'_id': {'lang': 'Italian, English, Sicilian'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Hakka'}, 'count': 1},
#  {'_id': {'lang': 'Saami, Norwegian, Swedish, Danish'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Arabic, Urdu'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, Thai'}, 'count': 1},
#  {'_id': {'lang': 'Wolof, English, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Spanish, German, Hindi, Polish'},
#   'count': 1},
#  {'_id': {'lang': 'English, Italian, Swedish'}, 'count': 2},
#  {'_id': {'lang': 'French, German'}, 'count': 37},
#  {'_id': {'lang': 'Hindi, Russian'}, 'count': 1},
#  {'_id': {'lang': 'French, English, Spanish, Mandarin, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, English, Min Nan'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, Persian'}, 'count': 1},
#  {'_id': {'lang': 'Khmer, Vietnamese'}, 'count': 2},
#  {'_id': {'lang': 'French, Danish'}, 'count': 1},
#  {'_id': {'lang': 'Norwegian, English, Serbian, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Hmong'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Italian, Arabic'}, 'count': 2},
#  {'_id': {'lang': 'English, Spanish, Irish'}, 'count': 1},
#  {'_id': {'lang': 'French, Albanian, Russian'}, 'count': 1},
#  {'_id': {'lang': 'German, English, Arabic, French'}, 'count': 1},
#  {'_id': {'lang': 'Serbo-Croatian, German, English'}, 'count': 1},
#  {'_id': {'lang': 'French, Romany, Turkish, Slovak, Rajasthani, Hungarian, '
#                   'Arabic, Spanish'},
#   'count': 1},
#  {'_id': {'lang': 'French, Japanese, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Dutch, Romanian, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Indonesian, English'}, 'count': 3},
#  {'_id': {'lang': 'Thai, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Portuguese, French, German'}, 'count': 1},
#  {'_id': {'lang': 'Russian, Italian, Tatar'}, 'count': 1},
#  {'_id': {'lang': 'French, English, Chinese'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, German'}, 'count': 2},
#  {'_id': {'lang': 'Turkish, French, Greek'}, 'count': 1},
#  {'_id': {'lang': 'Icelandic, French'}, 'count': 3},
#  {'_id': {'lang': 'English, Russian, Dutch'}, 'count': 1},
#  {'_id': {'lang': 'Portuguese, Italian, German'}, 'count': 2},
#  {'_id': {'lang': 'Cantonese, English, Ungwatsi'}, 'count': 1},
#  {'_id': {'lang': 'English, Japanese, Hebrew, Portuguese, French, Arabic, '
#                   'Filipino, German'},
#   'count': 1},
#  {'_id': {'lang': 'English, German, Hebrew, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, Polish, French, Spanish, German'},
#   'count': 1},
#  {'_id': {'lang': 'English, French, Serbo-Croatian'}, 'count': 1},
#  {'_id': {'lang': 'French, Bambara'}, 'count': 1},
#  {'_id': {'lang': 'German, Russian, Czech'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, Swedish, English'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Hokkien, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, Swahili, German'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, Afrikaans'}, 'count': 1},
#  {'_id': {'lang': 'French, Spanish, Polish'}, 'count': 1},
#  {'_id': {'lang': 'French, German, Portuguese, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Cantonese, Italian'}, 'count': 1},
#  {'_id': {'lang': 'French, French Sign Language'}, 'count': 1},
#  {'_id': {'lang': 'Estonian, Russian, English, French, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Greek, French, Hungarian'}, 'count': 1},
#  {'_id': {'lang': 'Turkish, Italian'}, 'count': 1},
#  {'_id': {'lang': 'German, Norwegian, English'}, 'count': 1},
#  {'_id': {'lang': 'Italian, German, English'}, 'count': 5},
#  {'_id': {'lang': 'English, Russian, Turkish, Romany'}, 'count': 1},
#  {'_id': {'lang': 'English, Swedish'}, 'count': 38},
#  {'_id': {'lang': 'Cantonese, Japanese, Korean, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Cantonese'}, 'count': 30},
#  {'_id': {'lang': 'English, French, German, Turkish, Italian, Swedish'},
#   'count': 1},
#  {'_id': {'lang': 'Swedish, Russian, English'}, 'count': 2},
#  {'_id': {'lang': 'German, Czech'}, 'count': 3},
#  {'_id': {'lang': 'English, Syriac, German, Greek, Hebrew, Latin, Aramaic'},
#   'count': 1},
#  {'_id': {'lang': 'English, French, Spanish, Korean, Chinese'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, Russian, French, Chinese'}, 'count': 2},
#  {'_id': {'lang': 'English, Hungarian, French, German'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, English, Hungarian'}, 'count': 1},
#  {'_id': {'lang': 'Georgian, Russian, English, Armenian'}, 'count': 1},
#  {'_id': {'lang': 'Hopi, English, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, English, Italian, French, German'}, 'count': 1},
#  {'_id': {'lang': 'Italian, French, Latin, Chinese'}, 'count': 1},
#  {'_id': {'lang': 'Polish, Yiddish, Hebrew, German'}, 'count': 1},
#  {'_id': {'lang': 'Turkish, Greek, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, Spanish, Indonesian, Danish'}, 'count': 1},
#  {'_id': {'lang': 'Russian, German, French'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Sicilian'}, 'count': 1},
#  {'_id': {'lang': 'French, German, Danish'}, 'count': 1},
#  {'_id': {'lang': 'English, Esperanto'}, 'count': 6},
#  {'_id': {'lang': 'English, Italian, Latin'}, 'count': 2},
#  {'_id': {'lang': 'Turkish, Swiss German, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, Arabic, Hebrew'}, 'count': 7},
#  {'_id': {'lang': 'English, Syriac, Aramaic, Italian, Latin'}, 'count': 1},
#  {'_id': {'lang': 'Hungarian, English, German'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Hindi, Panjabi'}, 'count': 1},
#  {'_id': {'lang': 'Italian, German, English, French, Latin, Spanish'},
#   'count': 1},
#  {'_id': {'lang': 'Korean, Cantonese, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'Catalan, Spanish'}, 'count': 4},
#  {'_id': {'lang': 'Norwegian, English, German, Danish'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, German, English, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Swahili, Xhosa, Zulu'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, German, French, Russian'}, 'count': 1},
#  {'_id': {'lang': 'French, Japanese, English, German'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, English, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Russian, Hebrew, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Mandarin, Japanese, Cantonese'}, 'count': 1},
#  {'_id': {'lang': 'English, Danish, German, Polish'}, 'count': 1},
#  {'_id': {'lang': 'Czech, Polish, English'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Cantonese, Japanese, Hungarian'},
#   'count': 1},
#  {'_id': {'lang': 'English, German, French, Hebrew, Arabic, Italian, Greek, '
#                   'Russian'},
#   'count': 1},
#  {'_id': {'lang': 'English, Cantonese, Japanese, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'English, Arabic, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Bhojpuri'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Min Nan, Korean, English'}, 'count': 1},
#  {'_id': {'lang': 'Norwegian'}, 'count': 83},
#  {'_id': {'lang': 'Cantonese, Mandarin, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'Maori'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Japanese, English'}, 'count': 4},
#  {'_id': {'lang': 'Telugu, Tamil, Hindi, Malayalam'}, 'count': 2},
#  {'_id': {'lang': 'German, Spanish'}, 'count': 6},
#  {'_id': {'lang': 'Korean, Japanese'}, 'count': 7},
#  {'_id': {'lang': 'English, Cantonese'}, 'count': 41},
#  {'_id': {'lang': 'Portuguese, Kabuverdianu'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Cantonese, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Danish, Turkish, English, Chinese'}, 'count': 2},
#  {'_id': {'lang': 'Hebrew, Arabic, French'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Arabic, French, Cantonese'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, English, German, French, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Hebrew, Yiddish'}, 'count': 3},
#  {'_id': {'lang': 'Swedish, Spanish, English, French, Danish, Arabic'},
#   'count': 1},
#  {'_id': {'lang': 'French, Mandarin, English, Hebrew'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Polish'}, 'count': 2},
#  {'_id': {'lang': 'Cantonese, English, Chinese'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, German, French, Finnish'}, 'count': 1},
#  {'_id': {'lang': 'English, Portuguese, French, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'English, Mandarin, Spanish'}, 'count': 4},
#  {'_id': {'lang': 'Spanish, French'}, 'count': 20},
#  {'_id': {'lang': 'Hebrew, Arabic, German, French'}, 'count': 1},
#  {'_id': {'lang': 'Russian Sign Language, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Ibo'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Catalan'}, 'count': 1},
#  {'_id': {'lang': 'English, Sanskrit, German, French, Italian, Russian, '
#                   'Romanian, Mandarin, Latin, Armenian, Egyptian (Ancient)'},
#   'count': 1},
#  {'_id': {'lang': 'English, German, Spanish, Russian, Czech'}, 'count': 1},
#  {'_id': {'lang': 'Slovenian'}, 'count': 8},
#  {'_id': {'lang': 'English, Armenian, French, German, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'Tajik, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Turkish, Kurdish'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, English, French, Spanish, Danish, Finnish, '
#                   'Hebrew, Italian, Japanese, Portuguese, Russian, Yiddish'},
#   'count': 1},
#  {'_id': {'lang': 'English, Italian, Latin, French'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, English, Japanese, Shanghainese'}, 'count': 2},
#  {'_id': {'lang': 'English, Russian, Spanish, Korean'}, 'count': 1},
#  {'_id': {'lang': 'Urdu'}, 'count': 8},
#  {'_id': {'lang': 'Polish, Yiddish, Hebrew, Latin'}, 'count': 1},
#  {'_id': {'lang': 'Bengali, English, Hindi, Panjabi'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Spanish, French, Croatian'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Klingon, Korean, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'English, French, German, Italian, Arabic, Spanish'},
#   'count': 1},
#  {'_id': {'lang': 'Polish, German, English, Ukrainian, Italian, German Sign '
#                   'Language'},
#   'count': 1},
#  {'_id': {'lang': 'Mandarin, Japanese, French, Russian, English'}, 'count': 1},
#  {'_id': {'lang': 'Amharic, Afrikaans'}, 'count': 1},
#  {'_id': {'lang': 'English, Dutch, German, Latin, French'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Japanese, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Portuguese, Guarani, English'}, 'count': 1},
#  {'_id': {'lang': 'Persian, Arabic, English'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, Italian, French'}, 'count': 1},
#  {'_id': {'lang': 'Korean, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Italian, German, Serbian, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Japanese, French, German, Italian, Spanish, English, '
#                   'Russian'},
#   'count': 1},
#  {'_id': {'lang': 'English, Danish, Swedish'}, 'count': 1},
#  {'_id': {'lang': 'English, Icelandic'}, 'count': 10},
#  {'_id': {'lang': 'Finnish, German, Swedish'}, 'count': 2},
#  {'_id': {'lang': 'Macedonian'}, 'count': 2},
#  {'_id': {'lang': 'English, Spanish, French, German, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Panjabi, Marathi, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Hawaiian, German, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'English, Acholi'}, 'count': 1},
#  {'_id': {'lang': 'English, Mandarin, Japanese, German'}, 'count': 1},
# ...
#  {'_id': {'lang': 'English, Japanese, Latin'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Panjabi, English'}, 'count': 4},
#  {'_id': {'lang': 'Polish, German, Yiddish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'French, Inuktitut'}, 'count': 2},
#  {'_id': {'lang': 'English, French, Portuguese, German'}, 'count': 2},
#  {'_id': {'lang': 'English, Italian, German'}, 'count': 8},
#  {'_id': {'lang': 'Wolof'}, 'count': 2},
#  {'_id': {'lang': 'English, German, Hebrew, Russian, French'}, 'count': 1},
#  {'_id': {'lang': 'Thai, Indian Sign Language'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Czech'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, Turkmen, English'}, 'count': 1},
#  {'_id': {'lang': 'English, German, French, Latin'}, 'count': 2},
#  {'_id': {'lang': 'Turkish, French, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, American Sign Language, Dutch, Italian, Russian, '
#                   'Swahili'},
#   'count': 1},
#  {'_id': {'lang': 'Catalan, Hebrew'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, Polish'}, 'count': 3},
#  {'_id': {'lang': 'Hokkien, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'English, Urdu'}, 'count': 8},
#  {'_id': {'lang': 'Telugu, Tamil, Malayalam'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Spanish, French'}, 'count': 1},
#  {'_id': {'lang': 'German, Slovak, Russian, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Greek,  Ancient (to 1453)'}, 'count': 2},
#  {'_id': {'lang': 'Portuguese, Tupi'}, 'count': 1},
#  {'_id': {'lang': 'French, English, Hungarian'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Chinese'}, 'count': 5},
#  {'_id': {'lang': 'Spanish, Catalan, French'}, 'count': 1},
#  {'_id': {'lang': 'English, German, French'}, 'count': 40},
#  {'_id': {'lang': 'English, Yiddish, German'}, 'count': 3},
#  {'_id': {'lang': 'Panjabi, Hindi, English'}, 'count': 1},
#  {'_id': {'lang': 'Sicilian, Italian, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Hindi, Bengali, French'}, 'count': 1},
#  {'_id': {'lang': 'Indian Sign Language, Hindi'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, German, Italian, Polish'}, 'count': 1},
#  {'_id': {'lang': 'Serbo-Croatian, English'}, 'count': 4},
#  {'_id': {'lang': 'Japanese, English, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'French, Polish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Korean, German, Japanese, Mandarin, Russian, English'},
#   'count': 1},
#  {'_id': {'lang': 'English, Spanish, Latin, French'}, 'count': 1},
#  {'_id': {'lang': 'German, English, Turkish, Bulgarian, Serbo-Croatian, '
#                   'Romanian'},
#   'count': 1},
#  {'_id': {'lang': 'Zulu'}, 'count': 1},
#  {'_id': {'lang': 'Estonian, Russian, Georgian'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, English, Estonian'}, 'count': 1},
#  {'_id': {'lang': 'English, Japanese, Icelandic'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, German, Finnish, English'}, 'count': 1},
#  {'_id': {'lang': 'French, Romanian, English'}, 'count': 1},
#  {'_id': {'lang': 'Korean, Cantonese'}, 'count': 1},
#  {'_id': {'lang': 'English, Japanese, Italian'}, 'count': 2},
#  {'_id': {'lang': 'Flemish, French, English'}, 'count': 1},
#  {'_id': {'lang': 'French, Hebrew'}, 'count': 1},
#  {'_id': {'lang': 'Norwegian, Urdu'}, 'count': 1},
#  {'_id': {'lang': 'East-Greenlandic, English'}, 'count': 1},
#  {'_id': {'lang': 'Finnish, Russian'}, 'count': 8},
#  {'_id': {'lang': 'English, Danish, Spanish'}, 'count': 2},
#  {'_id': {'lang': 'Cantonese, Shanghainese, French'}, 'count': 3},
#  {'_id': {'lang': 'French, Japanese'}, 'count': 10},
#  {'_id': {'lang': 'Sardinian, French, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, German, English, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Latin, Greek, French, German, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Latvian, German, Russian, French, English'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Italian, Catalan, English'}, 'count': 1},
#  {'_id': {'lang': 'German, Bosnian'}, 'count': 1},
#  {'_id': {'lang': 'German, English, French, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, Dinka, English'}, 'count': 1},
#  {'_id': {'lang': 'Japanese, French, Italian, Thai, English'}, 'count': 1},
#  {'_id': {'lang': 'Serbian, Romany'}, 'count': 1},
#  {'_id': {'lang': 'Spanish, Guarani, Korean'}, 'count': 1},
#  {'_id': {'lang': 'Serbo-Croatian, Croatian'}, 'count': 1},
#  {'_id': {'lang': 'Russian, Kazakh'}, 'count': 1},
#  {'_id': {'lang': 'English, Icelandic, Japanese, German'}, 'count': 1},
#  {'_id': {'lang': 'Polish, Russian, Serbo-Croatian'}, 'count': 1},
#  {'_id': {'lang': 'French, Spanish, English, Catalan, Danish, German, Italian'},
#   'count': 1},
#  {'_id': {'lang': 'French, German, English, Flemish, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, Finnish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'German, Swiss German'}, 'count': 3},
#  {'_id': {'lang': 'French, English, Cantonese'}, 'count': 4},
#  {'_id': {'lang': 'English, Arabic, Spanish'}, 'count': 4},
#  {'_id': {'lang': 'Romanian, Russian, English'}, 'count': 2},
#  {'_id': {'lang': 'English, Japanese, German'}, 'count': 4},
#  {'_id': {'lang': 'Cantonese, English, Vietnamese, French'}, 'count': 1},
#  {'_id': {'lang': 'French, German, English, Italian'}, 'count': 2},
#  {'_id': {'lang': 'Spanish, German, Catalan'}, 'count': 1},
#  {'_id': {'lang': 'English, Persian, French, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, Yiddish, Russian, French, Italian, Romany, '
#                   'Romanian'},
#   'count': 1},
#  {'_id': {'lang': 'Icelandic, Greenlandic'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, English, Kannada, Marathi'}, 'count': 1},
#  {'_id': {'lang': 'English, Latin, Hungarian'}, 'count': 1},
#  {'_id': {'lang': 'French, English, Norwegian, German, Swedish, Danish'},
#   'count': 1},
#  {'_id': {'lang': 'Spanish, English, German'}, 'count': 2},
#  {'_id': {'lang': 'Cantonese, English, Thai, Vietnamese'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, Tigrigna'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, Aboriginal'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Japanese, Mandarin, Latin'}, 'count': 1},
#  {'_id': {'lang': 'Belarusian, Russian, German'}, 'count': 2},
#  {'_id': {'lang': 'Spanish, Polish, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Czech, Slovak, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Yiddish'}, 'count': 23},
#  {'_id': {'lang': 'Italian, Romanian'}, 'count': 3},
#  {'_id': {'lang': 'Norwegian, French, English'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Serbian'}, 'count': 1},
#  {'_id': {'lang': 'French, Italian, English, Arabic'}, 'count': 2},
#  {'_id': {'lang': 'Polish, Hungarian'}, 'count': 1},
#  {'_id': {'lang': 'Danish, English, Czech'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, French, German'}, 'count': 4},
#  {'_id': {'lang': 'English, Greek, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Georgian'}, 'count': 18},
#  {'_id': {'lang': 'Swedish, Saami'}, 'count': 1},
#  {'_id': {'lang': 'German, English, Pushto, Dari'}, 'count': 1},
#  {'_id': {'lang': 'German, Italian, English'}, 'count': 4},
#  {'_id': {'lang': 'Arabic'}, 'count': 32},
#  {'_id': {'lang': 'English, Chinese'}, 'count': 19},
#  {'_id': {'lang': 'English, Spanish, Russian, Dari, French'}, 'count': 1},
#  {'_id': {'lang': 'Italian, Spanish'}, 'count': 24},
#  {'_id': {'lang': 'English, Romanian, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'English, Romanian, French'}, 'count': 3},
#  {'_id': {'lang': 'English, Danish'}, 'count': 16},
#  {'_id': {'lang': 'French, Spanish, Japanese, English'}, 'count': 1},
#  {'_id': {'lang': 'German, Turkish, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'French, Russian, English'}, 'count': 5},
#  {'_id': {'lang': 'English, Italian, Spanish, Balinese'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Bambara, Jola-Fonyi, Swahili'}, 'count': 1},
#  {'_id': {'lang': 'Swiss German'}, 'count': 11},
#  {'_id': {'lang': 'English, Brazilian Sign Language, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Japanese, English, French'}, 'count': 2},
#  {'_id': {'lang': 'Spanish, Catalan, English, French'}, 'count': 1},
#  {'_id': {'lang': 'Portuguese, English, Polish'}, 'count': 1},
#  {'_id': {'lang': 'French, Russian, English, Spanish, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Korean, Mandarin, English'}, 'count': 1},
#  {'_id': {'lang': 'Sinhalese'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, French, English'}, 'count': 2},
#  {'_id': {'lang': 'Hindi, Tamil, English, Marathi'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian'}, 'count': 263},
#  {'_id': {'lang': 'English, Vietnamese, German, Japanese, Portuguese'},
#   'count': 1},
#  {'_id': {'lang': 'French, English, Korean, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Turkish, German, Kurdish, English'}, 'count': 1},
#  {'_id': {'lang': 'Serbo-Croatian'}, 'count': 20},
#  {'_id': {'lang': 'French, German, English, Khmer'}, 'count': 1},
#  {'_id': {'lang': 'English, Urdu, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'French, German, Yiddish'}, 'count': 1},
#  {'_id': {'lang': 'Malay, Mandarin, English, Cantonese'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, English, Rajasthani'}, 'count': 2},
#  {'_id': {'lang': 'French, Bambara, English, Hebrew'}, 'count': 1},
#  {'_id': {'lang': 'Danish, German, Persian, English, French'}, 'count': 1},
#  {'_id': {'lang': 'Vietnamese, English, Mandarin, Cantonese, Malay'},
#   'count': 1},
#  {'_id': {'lang': 'English, French, Portuguese, Spanish'}, 'count': 2},
#  {'_id': {'lang': 'Hindi, English, Russian, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, German, Japanese, Serbo-Croatian'}, 'count': 1},
#  {'_id': {'lang': 'Swedish, French'}, 'count': 2},
#  {'_id': {'lang': 'Hindi, Panjabi'}, 'count': 4},
#  {'_id': {'lang': 'Czech, German, English, Slovak'}, 'count': 2},
#  {'_id': {'lang': 'Kurdish, Persian'}, 'count': 3},
#  {'_id': {'lang': 'English, Kurdish, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'French, English, Portuguese'}, 'count': 4},
#  {'_id': {'lang': 'Hindi, Marathi, Bengali, English, Portuguese'}, 'count': 1},
#  {'_id': {'lang': 'English, Romanian, Czech'}, 'count': 1},
#  {'_id': {'lang': 'French, German, Italian'}, 'count': 3},
#  {'_id': {'lang': 'Russian, English'}, 'count': 35},
#  {'_id': {'lang': 'Spanish, Quechua'}, 'count': 5},
#  {'_id': {'lang': 'English, French, Spanish, Arabic, Italian'}, 'count': 1},
#  {'_id': {'lang': 'Persian, Azerbaijani'}, 'count': 5},
#  {'_id': {'lang': 'Polish, Russian, Vietnamese'}, 'count': 1},
#  {'_id': {'lang': 'English, French, Urdu, Arabic'}, 'count': 2},
#  {'_id': {'lang': 'German, French, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'Min Nan, Malay, Mandarin, Bengali'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Telugu, Tamil'}, 'count': 3},
#  {'_id': {'lang': 'Mandarin, Cantonese, Tagalog'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, English, Urdu'}, 'count': 3},
#  {'_id': {'lang': 'English, Italian, German, Swiss German, Danish'},
#   'count': 1},
#  {'_id': {'lang': 'French, German, Corsican'}, 'count': 2},
#  {'_id': {'lang': 'French, English, German, Italian'}, 'count': 7},
#  {'_id': {'lang': 'English, Icelandic, Russian, French'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Bengali, Hindi, Spanish, English'}, 'count': 1},
#  {'_id': {'lang': 'Danish, Swedish'}, 'count': 11},
#  {'_id': {'lang': 'Spanish, Guarani'}, 'count': 4},
#  {'_id': {'lang': 'Hebrew, Polish'}, 'count': 1},
#  {'_id': {'lang': 'English, Cantonese, Dutch'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Cantonese, Thai'}, 'count': 1},
#  {'_id': {'lang': 'English, Swedish, Norwegian, Danish, Icelandic, French'},
#   'count': 1},
#  {'_id': {'lang': 'English, Tagalog, Cantonese, Mandarin, Spanish'},
#   'count': 1},
#  {'_id': {'lang': 'Finnish, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Danish, Polish, French'}, 'count': 1},
#  {'_id': {'lang': 'English, Cree'}, 'count': 2},
#  {'_id': {'lang': 'Hindi, Urdu, English, Panjabi'}, 'count': 1},
#  {'_id': {'lang': 'Quechua, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'English, French, German, Luxembourgish, Arabic'},
#   'count': 1},
#  {'_id': {'lang': 'Greek, German'}, 'count': 1},
#  {'_id': {'lang': 'Lithuanian, Russian, English'}, 'count': 1},
#  {'_id': {'lang': 'English, Norwegian, French, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Turkish, Greek, Kurdish'}, 'count': 1},
#  {'_id': {'lang': 'Norwegian, Swedish, English'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, English, Hokkien, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'English, Mandarin, Sanskrit'}, 'count': 1},
#  {'_id': {'lang': 'English, Russian, Hungarian, French'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, English, French, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'English, Tibetan'}, 'count': 2},
#  {'_id': {'lang': 'English, Aramaic'}, 'count': 1},
#  {'_id': {'lang': 'English, Dutch, Indonesian, Mandarin, Spanish, Korean'},
#   'count': 1},
#  {'_id': {'lang': 'English, Irish, Aboriginal'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, German, English, Eastern Frisian'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Polish, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Bulgarian, French'}, 'count': 1},
#  {'_id': {'lang': 'Finnish'}, 'count': 349},
#  {'_id': {'lang': 'English, French, Italian'}, 'count': 32},
#  {'_id': {'lang': 'Romany, Japanese, German'}, 'count': 1},
#  {'_id': {'lang': 'English, Icelandic, Italian'}, 'count': 2},
#  {'_id': {'lang': 'English, Greek, German'}, 'count': 2},
#  {'_id': {'lang': 'Bulgarian'}, 'count': 6},
#  {'_id': {'lang': 'Danish, English'}, 'count': 11},
#  {'_id': {'lang': 'Polish, Serbo-Croatian, Italian, German, French, English'},
#   'count': 1},
#  {'_id': {'lang': 'English, Spanish, Italian'}, 'count': 11},
#  {'_id': {'lang': 'Polish, English, French, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Italian, Japanese, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Panjabi, Urdu'}, 'count': 2},
#  {'_id': {'lang': 'Persian, Turkish, English'}, 'count': 1},
#  {'_id': {'lang': 'French, Romanian'}, 'count': 7},
#  {'_id': {'lang': 'Korean, Mandarin, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'Lingala'}, 'count': 1},
#  {'_id': {'lang': 'Hindi, Panjabi, English, French, Tamil'}, 'count': 1},
#  {'_id': {'lang': 'English, Hungarian, Spanish, French'}, 'count': 1},
#  {'_id': {'lang': 'Korean, Cantonese, English, Mandarin, Japanese'},
#   'count': 1},
#  {'_id': {'lang': 'French, Kurdish, English, Turkish'}, 'count': 1},
#  {'_id': {'lang': 'Bengali, Hindi'}, 'count': 1},
#  {'_id': {'lang': 'Korean, English, French'}, 'count': 4},
#  {'_id': {'lang': 'Spanish, English, Ewe'}, 'count': 1},
#  {'_id': {'lang': 'Hungarian, Russian, English'}, 'count': 1},
#  {'_id': {'lang': 'Kurdish, Arabic, English'}, 'count': 2},
#  {'_id': {'lang': 'Spanish, Yiddish'}, 'count': 1},
#  {'_id': {'lang': 'English, Cantonese, French, German, Hindi, Turkish'},
#   'count': 1},
#  {'_id': {'lang': 'English, Portuguese, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, Hindi, Urdu'}, 'count': 2},
#  {'_id': {'lang': 'Chinese, English'}, 'count': 3},
#  {'_id': {'lang': 'Spanish, Chinese, Wolof'}, 'count': 1},
#  {'_id': {'lang': 'English, Spanish, Arabic'}, 'count': 1},
#  {'_id': {'lang': 'French, Armenian'}, 'count': 2},
#  {'_id': {'lang': 'Portuguese, French, German, Italian'}, 'count': 1},
#  {'_id': {'lang': 'English, Malayalam'}, 'count': 1},
#  {'_id': {'lang': 'Georgian, Hebrew'}, 'count': 1},
#  {'_id': {'lang': 'Dutch, German, Polish'}, 'count': 1},
#  {'_id': {'lang': 'Cantonese, Thai, Mandarin'}, 'count': 1},
#  {'_id': {'lang': 'French, Arabic'}, 'count': 27},
#  {'_id': {'lang': 'English, French, Wolof, Spanish'}, 'count': 1},
#  {'_id': {'lang': 'Oriya, English'}, 'count': 1},
#  {'_id': {'lang': 'Italian, German'}, 'count': 24},
#  {'_id': {'lang': 'Japanese, Russian, Korean'}, 'count': 1},
#  {'_id': {'lang': 'Tamil, Hindi, English'}, 'count': 3},
#  {'_id': {'lang': 'English, Spanish, Arabic, French, Japanese'}, 'count': 1},
#  {'_id': {'lang': 'Swahili'}, 'count': 2},
#  {'_id': {'lang': 'Swedish, English, Russian'}, 'count': 1},
#  {'_id': {'lang': 'English, Hawaiian, Russian'}, 'count': 1},
#  {'_id': {'lang': 'Malayalam, Nepali'}, 'count': 1},
#  {'_id': {'lang': 'Mandarin, Tagalog, English, Cantonese'}, 'count': 1},
#  {'_id': {'lang': 'English, Finnish, French, German, Dutch'}, 'count': 1},
#  {'_id': {'lang': 'Thai, Korean'}, 'count': 2},
#  {'_id': {'lang': 'German, English, French, Polish'}, 'count': 1}]
